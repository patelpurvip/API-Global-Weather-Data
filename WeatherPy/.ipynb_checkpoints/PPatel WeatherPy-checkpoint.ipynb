# %% [markdown]
# # PPatel WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-ea8fb1d88a98> in <module>
#      10
#      11 # Import API key
# ---> 12 from api_keys import weather_api_key
#      13
#      14 # Incorporated citipy to determine city based on latitude and longitude
#
# ModuleNotFoundError: No module named 'api_keys'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %%
#print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build partial query URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
weather_url = f"{base_url}appid={weather_api_key}&units={units}&q="

city_info = []

for city in cities:
    try:
        weather_data = requests.get(weather_url+city).json()
        lat = weather_data['coord']['lat']
        lon = weather_data['coord']['lon']
        temp = weather_data['main']['temp']
        humidity = weather_data['main']['humidity']
        cloudiness = weather_data['clouds']['all']
        windspeed = weather_data['wind']['speed']
        print(f"Processing Record {city}")
    except KeyError:
        print(f"Some data not found. Skipping {city}")
        continue
    city_dict = {
            "city": city,
            "lat": lat,
            "lon": lon,
            "temp": temp,
            "humidity": humidity,
            "cloudiness": cloudiness,
            "windspeed": windspeed}
    city_info.append(city_dict)
    
#pprint(weather_data)
# Out:
# Processing Record melfort
# Processing Record tuatapere
# Processing Record rikitea
# Processing Record pangai
# Processing Record rocha
# Processing Record gazojak
# Processing Record hamilton
# Processing Record ushuaia
# Some data not found. Skipping palabuhanratu
# Some data not found. Skipping tsihombe
# Processing Record atuona
# Processing Record tiksi
# Processing Record saint-pierre
# Processing Record busselton
# Processing Record vanimo
# Processing Record the valley
# Processing Record punta arenas
# Processing Record praia da vitoria
# Processing Record westport
# Processing Record chokurdakh
# Some data not found. Skipping taolanaro
# Processing Record hithadhoo
# Processing Record hermanus
# Processing Record mataura
# Processing Record ilebo
# Processing Record ust-kulom
# Processing Record airai
# Some data not found. Skipping dalinghe
# Processing Record chuy
# Processing Record lalmohan
# Processing Record kapaa
# Processing Record barrow
# Processing Record khatanga
# Some data not found. Skipping illoqqortoormiut
# Processing Record butaritari
# Processing Record saint augustine
# Processing Record faya
# Processing Record port alfred
# Processing Record yulara
# Processing Record ixtapa
# Processing Record nantucket
# Processing Record lorengau
# Processing Record banda aceh
# Processing Record lompoc
# Processing Record andenes
# Processing Record tasiilaq
# Processing Record ostrovnoy
# Processing Record lebu
# Processing Record cherskiy
# Processing Record labrea
# Processing Record bathsheba
# Processing Record avarua
# Processing Record ambalavao
# Some data not found. Skipping yakshur-bodya
# Processing Record tabuk
# Processing Record dikson
# Processing Record new norfolk
# Some data not found. Skipping belushya guba
# Processing Record albany
# Processing Record namibe
# Some data not found. Skipping vaitupu
# Processing Record maura
# Processing Record bluff
# Processing Record russell
# Processing Record tomatlan
# Processing Record hambantota
# Processing Record ketchikan
# Processing Record hobart
# Processing Record hargeysa
# Processing Record mahebourg
# Processing Record bosaso
# Processing Record cape town
# Processing Record diapaga
# Processing Record mandalgovi
# Processing Record qaanaaq
# Processing Record ust-omchug
# Processing Record golden
# Processing Record vaini
# Processing Record pathein
# Processing Record yellowknife
# Processing Record bengkulu
# Some data not found. Skipping saleaula
# Processing Record taoudenni
# Processing Record hervey bay
# Processing Record kenmore
# Processing Record linjiang
# Processing Record iqaluit
# Processing Record borogontsy
# Processing Record saint-philippe
# Some data not found. Skipping sedelnikovo
# Processing Record zlotow
# Processing Record hilo
# Processing Record aklavik
# Some data not found. Skipping mys shmidta
# Processing Record bethel
# Processing Record shimoda
# Processing Record kalmunai
# Some data not found. Skipping samusu
# Processing Record katsuura
# Processing Record bredasdorp
# Processing Record kutum
# Processing Record port hawkesbury
# Processing Record monkey bay
# Processing Record pacific grove
# Processing Record charters towers
# Processing Record mafinga
# Processing Record antofagasta
# Processing Record chaadayevka
# Processing Record arraial do cabo
# Processing Record santa rosa
# Processing Record sterling
# Processing Record kamuli
# Processing Record panguipulli
# Processing Record araouane
# Processing Record diamantino
# Processing Record camacha
# Processing Record east london
# Processing Record shu
# Processing Record petropavlovsk-kamchatskiy
# Processing Record puerto ayora
# Some data not found. Skipping sentyabrskiy
# Some data not found. Skipping bocaranga
# Processing Record provideniya
# Processing Record bereznik
# Processing Record castro
# Processing Record paslek
# Processing Record vuktyl
# Processing Record willowmore
# Processing Record la rioja
# Processing Record hobyo
# Processing Record muzhi
# Some data not found. Skipping karauzyak
# Processing Record alofi
# Processing Record georgetown
# Processing Record akom
# Processing Record takhtamygda
# Processing Record saint-leu
# Processing Record josanicka banja
# Processing Record honiara
# Processing Record robat karim
# Processing Record lannion
# Processing Record arman
# Processing Record jamestown
# Processing Record madinat sittah uktubar
# Processing Record alagoinha
# Processing Record montrose
# Processing Record mizdah
# Processing Record scarborough
# Processing Record tuktoyaktuk
# Some data not found. Skipping wa
# Processing Record mount vernon
# Processing Record souillac
# Processing Record liuli
# Processing Record vryburg
# Processing Record saskylakh
# Processing Record vila franca do campo
# Processing Record high level
# Processing Record vyshhorod
# Processing Record santa barbara
# Processing Record ewa beach
# Processing Record svetlaya
# Some data not found. Skipping mutsamudu
# Processing Record padang
# Processing Record virginia beach
# Processing Record belyy yar
# Processing Record katherine
# Processing Record werda
# Processing Record los llanos de aridane
# Processing Record astoria
# Processing Record kodiak
# Processing Record xining
# Processing Record komsomolskiy
# Processing Record san quintin
# Processing Record chegdomyn
# Processing Record leningradskiy
# Processing Record kaitangata
# Processing Record thompson
# Processing Record davila
# Processing Record margate
# Processing Record gravdal
# Processing Record abu samrah
# Processing Record alyangula
# Processing Record fomboni
# Processing Record amga
# Processing Record adrar
# Processing Record bela
# Processing Record pisco
# Processing Record ulladulla
# Processing Record innisfail
# Processing Record lewiston
# Processing Record pevek
# Processing Record constitucion
# Processing Record bambanglipuro
# Processing Record bolshaya sosnova
# Processing Record daitari
# Processing Record ventspils
# Processing Record sorland
# Processing Record christchurch
# Processing Record saint anthony
# Processing Record port hardy
# Processing Record waingapu
# Processing Record darfield
# Processing Record tual
# Processing Record atasu
# Some data not found. Skipping sorvag
# Processing Record torbay
# Processing Record edgewater
# Processing Record china
# Some data not found. Skipping grand river south east
# Processing Record smidovich
# Processing Record carnarvon
# Processing Record mitchell
# Processing Record linhares
# Processing Record kushima
# Processing Record spearfish
# Processing Record kiama
# Processing Record barcelos
# Processing Record dryden
# Processing Record taksimo
# Processing Record furano
# Processing Record moron
# Processing Record shar
# Some data not found. Skipping umzimvubu
# Processing Record ullapool
# Processing Record palmer
# Processing Record marsh harbour
# Processing Record anadyr
# Processing Record medea
# Processing Record ponta delgada
# Processing Record calama
# Some data not found. Skipping wazzan
# Processing Record gawler
# Processing Record tahoua
# Processing Record kjollefjord
# Processing Record ygatimi
# Some data not found. Skipping barentsburg
# Processing Record fare
# Processing Record pietersburg
# Processing Record vikhorevka
# Processing Record taltal
# Some data not found. Skipping amderma
# Processing Record longyearbyen
# Processing Record murdochville
# Processing Record moroni
# Processing Record turka
# Processing Record touros
# Processing Record qinzhou
# Processing Record dingle
# Processing Record marsabit
# Processing Record kavieng
# Processing Record husavik
# Processing Record ahuimanu
# Processing Record yatou
# Processing Record port lincoln
# Processing Record ribeira grande
# Processing Record te anau
# Processing Record broome
# Processing Record springbok
# Processing Record camocim
# Processing Record karasuk
# Processing Record acapulco
# Processing Record garowe
# Processing Record uyuni
# Processing Record vila velha
# Processing Record oktyabrskoye
# Processing Record sinnamary
# Processing Record kandrian
# Processing Record wilmington
# Processing Record norman wells
# Processing Record vestmannaeyjar
# Processing Record ilulissat
# Processing Record saint-georges
# Processing Record khakurinokhabl
# Processing Record upernavik
# Processing Record sistranda
# Processing Record koryukivka
# Processing Record moindou
# Processing Record gamboma
# Processing Record talcahuano
# Processing Record maputo
# Processing Record yar-sale
# Processing Record milkovo
# Processing Record belaya gora
# Processing Record chumikan
# Processing Record micheweni
# Processing Record mount isa
# Processing Record severo-kurilsk
# Processing Record felanitx
# Processing Record cabedelo
# Processing Record kota kinabalu
# Processing Record baker city
# Processing Record half moon bay
# Processing Record olafsvik
# Some data not found. Skipping toliary
# Processing Record bafq
# Processing Record palu
# Processing Record ponferrada
# Processing Record mula
# Processing Record jerecuaro
# Processing Record klaksvik
# Processing Record sao paulo de olivenca
# Processing Record seymchan
# Processing Record ambon
# Processing Record sitka
# Processing Record faanui
# Processing Record hay river
# Processing Record stromness
# Some data not found. Skipping katsiveli
# Processing Record elesbao veloso
# Processing Record tacoronte
# Processing Record port elizabeth
# Processing Record kasane
# Processing Record nikolskoye
# Processing Record batagay-alyta
# Processing Record oksbol
# Processing Record cabo san lucas
# Processing Record nuuk
# Processing Record caravelas
# Processing Record berlevag
# Processing Record matara
# Processing Record coquimbo
# Processing Record kurumkan
# Processing Record santa cruz
# Processing Record novovarshavka
# Some data not found. Skipping juifang
# Processing Record sorong
# Processing Record mar del plata
# Processing Record laguna
# Processing Record parana
# Processing Record dauphin
# Processing Record clyde river
# Some data not found. Skipping kegayli
# Processing Record chapais
# Processing Record lasa
# Processing Record puerto del rosario
# Processing Record nanortalik
# Processing Record whyalla
# Processing Record ginir
# Processing Record marawi
# Processing Record high river
# Processing Record charlottesville
# Processing Record kahului
# Processing Record cestas
# Processing Record qasigiannguit
# Processing Record ashtian
# Processing Record casablanca
# Processing Record bambous virieux
# Processing Record luderitz
# Processing Record sao miguel do araguaia
# Processing Record izberbash
# Some data not found. Skipping skagastrond
# Processing Record sabha
# Some data not found. Skipping umm durman
# Processing Record skibbereen
# Processing Record machelen
# Processing Record isangel
# Processing Record vanavara
# Processing Record cardston
# Processing Record ozernovskiy
# Processing Record mayya
# Processing Record bhatkal
# Processing Record lata
# Processing Record yubari
# Processing Record ulaangom
# Processing Record aksu
# Processing Record muriwai beach
# Processing Record thasra
# Processing Record hermosillo
# Processing Record talnakh
# Processing Record juodupe
# Processing Record celestun
# Processing Record baykit
# Processing Record ponta do sol
# Processing Record northam
# Processing Record mendi
# Processing Record imbituba
# Some data not found. Skipping litoral del san juan
# Some data not found. Skipping attawapiskat
# Processing Record huari
# Processing Record riga
# Processing Record samarai
# Processing Record markova
# Processing Record kosa
# Processing Record narsaq
# Processing Record mackay
# Processing Record porto nacional
# Some data not found. Skipping bargal
# Processing Record tinskoy
# Processing Record evanston
# Processing Record karur
# Processing Record sao joao de pirabas
# Processing Record canatlan
# Processing Record victoria
# Processing Record freeport
# Processing Record cayenne
# Processing Record ulaanbaatar
# Processing Record saint-louis
# Processing Record ust-nera
# Processing Record san remo
# Processing Record wanning
# Some data not found. Skipping ust-kamchatsk
# Processing Record pirenopolis
# Processing Record magadan
# Processing Record alagir
# Processing Record rawson
# Processing Record san juan
# Processing Record severo-yeniseyskiy
# Processing Record poum
# Processing Record saint george
# Processing Record kaabong
# Processing Record iralaya
# Processing Record zhigansk
# Processing Record south sioux city
# Processing Record fort nelson
# Processing Record cidreira
# Processing Record alindao
# Processing Record roncesvalles
# Processing Record sosua
# Processing Record port macquarie
# Processing Record batemans bay
# Processing Record porbandar
# Processing Record san patricio
# Processing Record quatre cocos
# Processing Record atambua
# Processing Record tabou
# Some data not found. Skipping nizhneyansk
# Processing Record sisophon
# Processing Record odweyne
# Processing Record berbera
# Some data not found. Skipping mrirt
# Processing Record bara
# Processing Record bonfim
# Processing Record muros
# Processing Record luanda
# Processing Record hereford
# Processing Record oussouye
# Processing Record mount gambier
# Processing Record mabay
# Processing Record kiunga
# Processing Record geraldton
# Processing Record santiago
# Processing Record kalach-na-donu
# Processing Record port blair
# Processing Record namatanai
# Some data not found. Skipping louisbourg
# Processing Record flinders
# Some data not found. Skipping agva
# Processing Record plettenberg bay
# Processing Record narasannapeta
# Processing Record tessalit
# Processing Record havoysund
# Processing Record izumo
# Processing Record inhambane
# Processing Record nueva loja
# Processing Record port augusta
# Processing Record hokitika
# Processing Record kruisfontein
# Processing Record sambava
# Processing Record guerrero negro
# Processing Record guiratinga
# Processing Record noshiro
# Processing Record ongandjera
# Processing Record ailigandi
# Processing Record horn
# Processing Record riyadh
# Processing Record samoylovka
# Processing Record olot
# Processing Record kamenka
# Processing Record vila do maio
# Processing Record piney green
# Processing Record nichinan
# Processing Record general roca
# Some data not found. Skipping mocambique
# Processing Record coihaique
# Processing Record amahai
# Processing Record rio gallegos
# Processing Record shetpe
# Processing Record port hedland
# Processing Record mrakovo
# Processing Record tornio
# Processing Record beringovskiy
# Processing Record praia
# Processing Record havelock
# Processing Record nisia floresta
# Processing Record yerbogachen
# Processing Record waitati
# Processing Record maceio
# Processing Record aldan
# Processing Record manikpur
# Some data not found. Skipping wulanhaote
# Processing Record kogon
# Processing Record jasper
# Processing Record kosonsoy
# Processing Record emerald
# Processing Record nizwa
# Some data not found. Skipping chengkung
# Processing Record vardo
# Processing Record hami
# Processing Record wanaka
# Processing Record krasnoselkup
# Processing Record kodinsk
# Processing Record grindavik
# Processing Record kupang
# Processing Record ust-tsilma
# Processing Record bogande
# Processing Record turukhansk
# Processing Record huaiyuan
# Processing Record burns lake
# Processing Record olinda
# Processing Record santa marta
# Processing Record salalah
# Some data not found. Skipping lugovskiy
# Processing Record kathmandu
# Processing Record sao filipe
# Processing Record kapuskasing
# Processing Record garissa
# Processing Record sao joao da barra
# Processing Record pozo colorado
# Processing Record boleslawiec
# Processing Record sisimiut
# Some data not found. Skipping grand centre
# Some data not found. Skipping kalimnos
# Processing Record esperance
# Processing Record quesnel
# Processing Record ijero
# Processing Record pangnirtung
# Processing Record malinovoye ozero
# Processing Record serebryanyy bor
# Processing Record porteirinha
# Processing Record san borja
# Processing Record cockburn town
# Processing Record payo
# Processing Record aloleng
# Processing Record moncton
# Processing Record waycross
# Processing Record chanika
# Processing Record cumberland
# Processing Record primorsko
# Processing Record himeji
# Processing Record banjar
# Processing Record angoram
# Processing Record ostersund
# Processing Record maraba
# Processing Record mattru
# Some data not found. Skipping cheuskiny
# Processing Record xichang
# Processing Record winchester
# Processing Record yuzhne
# Processing Record bam
# Processing Record kirakira
# Processing Record mandera
# Processing Record ampanihy
# Processing Record kintampo
# Processing Record talas
# Processing Record labuhan
# Processing Record rairangpur
# Some data not found. Skipping sataua
# Processing Record verkhoyansk
# Processing Record kununurra
# Processing Record pasighat
# Processing Record pimentel
# Processing Record malanje
# Processing Record fairbanks
# Processing Record aquiraz
# Some data not found. Skipping yellamanchili
# Processing Record bjornevatn
# Processing Record panguna
# Processing Record severnoye
# Processing Record teguise
# Some data not found. Skipping lolua
# Processing Record tiznit
# Processing Record houma
# Processing Record codrington
# Processing Record kuryk
# Processing Record jizan
# Processing Record belton
# Processing Record lagoa
# Processing Record sekoma
# Processing Record bubaque
# Processing Record lavrentiya
# Processing Record shingu
# Processing Record itaituba
# Processing Record bien hoa
# Processing Record two hills
# Processing Record rubiataba
# Processing Record yumen
# Processing Record rovaniemi
# Processing Record jumla
# Processing Record dongsheng
# Processing Record beira
# Processing Record paamiut
# Some data not found. Skipping viligili
# Processing Record alexandria
# Processing Record okhotsk
# Processing Record jackson
# Some data not found. Skipping rungata
# Processing Record kichmengskiy gorodok
# Processing Record baruun-urt
# Processing Record lakhtar
# Processing Record dosso
# Processing Record sonoita
# Processing Record kristiansand
# Processing Record fortuna
# Processing Record altay
# Processing Record pelym
# Processing Record atar
# Processing Record hofn
# Processing Record teknaf
# Processing Record fort saint james
# Processing Record slobozia
# Processing Record nome
# Processing Record shache
# Processing Record ocos
# Processing Record kokorevka
# Processing Record saldanha
# Processing Record karratha
# Processing Record potrerillos arriba
# Processing Record tautira
# Processing Record nanao
# Some data not found. Skipping chagda
# Processing Record neon karlovasion
# Processing Record baglung
# Processing Record sao jose da coroa grande
# Processing Record pasuruan
# Some data not found. Skipping malwan
# Processing Record usinsk
# Processing Record naze
# Processing Record altamont
# Processing Record kieta
# Processing Record staryy nadym

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(city_info)
weather_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9abef5cd588e> in <module>
# ----> 1 weather_df = pd.DataFrame(city_info)
#       2 weather_df.count()
#
# NameError: name 'pd' is not defined

# %%
weather_df.head()
# Out:
#         city    lat     lon   temp  humidity  cloudiness  windspeed
# 0    melfort  52.87 -104.62  41.00        60           1      14.99
# 1  tuatapere -46.13  167.68  43.00        93           2       1.01
# 2    rikitea -23.12 -134.97  79.29        80          70      11.61
# 3     pangai -19.80 -174.35  80.60        78          40      13.87
# 4      rocha -34.48  -54.33  78.94        68          79       8.68

# %%
weather_df.to_csv("../weatherdata.csv", encoding="utf-8", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-41116460c868> in <module>
# ----> 1 weather_df.to_csv("../weatherdata.csv", encoding="utf-8", index=False)
#
# NameError: name 'weather_df' is not defined

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_values = weather_df['lat']
y_values = weather_df['temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Global Sample: Latitude vs. Temperature (3/28/20)')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_values = weather_df['lat']
y_values = weather_df['humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Global Sample: Latitude vs. Humidity (3/28/20)')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_values = weather_df['lat']
y_values = weather_df['cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Global Sample: Latitude vs. Cloudiness (3/28/20)')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_values = weather_df['lat']
y_values = weather_df['windspeed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Global Sample: Latitude vs. Wind Speed (3/28/20)')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem_cities = weather_df.loc[weather_df["lat"] > 0]
southern_hem_cities = weather_df.loc[weather_df["lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Temp (F) vs. Latitude Linear Regression

# %%
x_values = northern_hem_cities['lat']
y_values = northern_hem_cities['temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(5,0),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Northern Hemisphere: Latitude vs. Temperature Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: -0.8839505367133862

# %% [markdown]
# ####  Southern Hemisphere - Temp (F) vs. Latitude Linear Regression

# %%
x_values = southern_hem_cities['lat']
y_values = southern_hem_cities['temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Southern Hemisphere: Latitude vs. Temperature Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: 0.6956300305771065

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hem_cities['lat']
y_values = northern_hem_cities['humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(45,5),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere: Latitude vs. Humidity Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: 0.3580680720924085

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hem_cities['lat']
y_values = southern_hem_cities['humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-23,15),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere: Latitude vs. Humidity Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: 0.05081534043710381

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hem_cities['lat']
y_values = northern_hem_cities['cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(45,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere: Latitude vs. Cloudiness Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: 0.24674471928513483

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hem_cities['lat']
y_values = southern_hem_cities['cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-55,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere: Latitude vs. Cloudiness Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: 0.24713179559742446

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hem_cities['lat']
y_values = northern_hem_cities['windspeed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere: Latitude vs. Wind Speed Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: 0.20081601297523405

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hem_cities['lat']
y_values = southern_hem_cities['windspeed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-25,21),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere: Latitude vs. Wind Speed Linear Regression (3/28/20)')

plt.show()
# Out:
# The r-squared is: -0.19801657936826686
